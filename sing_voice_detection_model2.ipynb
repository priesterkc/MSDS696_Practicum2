# %%
import pandas as pd
import numpy as np
import librosa
import glob
import os
import seaborn as sns

import IPython.display as ipd
import matplotlib.pyplot as plt
#import librosa.display

from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics

from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime

# %%
singers = {"1_izumi_iori":"iori",
          "2_nikaido_yamato":"yamato",
          "3_izumi_mitsuki":"mitsuki",
          "4_yotsuba_tamaki":"tamaki",
          "5_osaka_sougo":"sougo",
          "6_rokuya_nagi":"nagi",
          "7_nanase_riku":"riku",
          }

# %%
filenames = []
labels = []
folder = []

for file_folder, label in singers.items():
    
    filepath = f"datasets/music_files/{file_folder}/clips/"
    filelist = glob.glob(os.path.join(os.getcwd(), filepath, "*.mp3"))
    
    for file in filelist:
        filename = os.path.basename(file)
        
        folder.append(file_folder)
        filenames.append(filename)
        labels.append(singers[file_folder])

# %%
filename_dict = {"folder":folder,
                 "filenames":filenames,
                "labels":labels}

# %%
filename_df = pd.DataFrame(filename_dict)

filename_df.head()
# Out:
#          folder     filenames labels
# 0  1_izumi_iori    iori_1.mp3   iori
# 1  1_izumi_iori   iori_10.mp3   iori
# 2  1_izumi_iori  iori_100.mp3   iori
# 3  1_izumi_iori  iori_101.mp3   iori
# 4  1_izumi_iori  iori_102.mp3   iori

# %%
filename_df.tail()
# Out:
#             folder    filenames labels
# 994  7_nanase_riku  riku_95.mp3   riku
# 995  7_nanase_riku  riku_96.mp3   riku
# 996  7_nanase_riku  riku_97.mp3   riku
# 997  7_nanase_riku  riku_98.mp3   riku
# 998  7_nanase_riku  riku_99.mp3   riku

# %%
filename_df.count()
# Out:
# folder       999
# filenames    999
# labels       999
# dtype: int64

# %%
filename_df['labels'].unique()
# Out:
# array(['iori', 'yamato', 'mitsuki', 'tamaki', 'sougo', 'nagi', 'riku'],
#       dtype=object)

# %%
filename_df['labels'].value_counts()
# Out:
# riku       163
# mitsuki    157
# tamaki     145
# yamato     141
# nagi       133
# iori       132
# sougo      128
# Name: labels, dtype: int64

# %%
# transform audio data into MFCCs
# sr=None will use native sample rate of audio file

def features_extractor(file, sr=None):
    
    
    #load audio file - get sound_sample and sample_rate
    audio, sample_rate = librosa.load(file, sr=sr) 
    #extract mfcc, 1st and 2nd derivatives
    mfcc_features = librosa.feature.mfcc(y=audio, sr=sample_rate)
    mfcc1_features = librosa.feature.delta(mfcc_features,order=1)
    mfcc2_features = librosa.feature.delta(mfcc_features,order=2)
    #reduce dimensionality for scaled feature by calculating mean
    mfcc_scaled_features = np.mean(mfcc_features.T,axis=0)
    mfcc1_scaled_features = np.mean(mfcc1_features.T,axis=0)
    mfcc2_scaled_features = np.mean(mfcc2_features.T,axis=0)
    
    concat_mfcc_scaled = np.concatenate((mfcc_scaled_features, mfcc1_scaled_features, mfcc2_scaled_features))
    return concat_mfcc_scaled

# %%
# iterate through all audio files and extract features

extracted_features=[]

for index_num,row in filename_df.iterrows():
    
    file_folder = row['folder']
    dataset_path = f"datasets/music_files/{file_folder}/clips/"
    
    filepath = os.path.join(os.getcwd(), dataset_path, row['filenames'])
    
    feature_data=features_extractor(filepath)
    
    extracted_features.append(feature_data)

# %%
filename_df['features'] = extracted_features

filename_df.head()
# Out:
#          folder     filenames labels  \
# 0  1_izumi_iori    iori_1.mp3   iori
# 1  1_izumi_iori   iori_10.mp3   iori
# 2  1_izumi_iori  iori_100.mp3   iori
# 3  1_izumi_iori  iori_101.mp3   iori
# 4  1_izumi_iori  iori_102.mp3   iori
#
#                                             features
# 0  [-212.99126, 81.818504, -59.78514, 16.213083, ...
# 1  [-213.6378, 83.18009, -45.80968, 28.044502, -3...
# 2  [-208.48625, 88.34909, -23.720839, 37.77376, -...
# 3  [-221.32008, 102.64978, -24.54152, 30.993345, ...
# 4  [-244.0426, 94.649635, -20.543169, 33.919144, ...

# %%
# checking the value for the first row of data
# checking the shape of the array
filename_df['features'][0]
# Out:
# array([-2.12991257e+02,  8.18185043e+01, -5.97851410e+01,  1.62130833e+01,
#        -2.82210579e+01, -9.54763293e-01, -4.48582420e+01,  1.75307322e+00,
#        -1.66345387e+01, -8.28979301e+00, -1.63693485e+01,  2.10300970e+00,
#        -8.55566788e+00, -4.05240107e+00, -6.12985277e+00, -6.00301266e+00,
#        -1.33579950e+01, -1.06783886e+01, -4.16215086e+00, -1.15102015e+01,
#         1.01522613e+00,  1.16658375e-01,  2.99505711e-01,  2.53887177e-01,
#        -1.97675020e-01, -2.34436877e-02, -1.24401845e-01, -4.72518355e-02,
#        -1.22273818e-01, -7.91277215e-02, -9.40342620e-02, -4.02564146e-02,
#        -5.38735390e-02, -2.37187278e-03, -9.09994096e-02,  2.43451055e-02,
#        -1.10673234e-01, -1.54779423e-02, -3.62798423e-02, -1.25949845e-01,
#         6.36945218e-02,  4.47250716e-02,  6.02905564e-02, -2.96153370e-02,
#         3.77080850e-02,  7.02312589e-03,  1.22778760e-02,  1.66906994e-02,
#        -1.74562968e-02,  1.08389538e-02,  2.96856109e-02, -1.72340702e-02,
#         1.14990478e-04,  9.47092753e-03,  9.07634106e-03,  2.48158108e-02,
#         2.84831114e-02, -1.33868679e-02,  1.31474109e-02,  2.66730879e-02],
#       dtype=float32)

# %%
# length of a feature array - this will be used in model input shape
filename_df['features'][0].shape
# Out:
# (60,)

# %%
# separate input features from output variables
X=np.array(filename_df['features'].tolist())
y=np.array(filename_df['labels'].tolist())

# %%
# change word category labels into numerical category labels
labelencoder=LabelEncoder()
y=to_categorical(labelencoder.fit_transform(y))

# %%
# separate into train and test data
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=97)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (799, 60)
# (200, 60)
# (799, 7)
# (200, 7)

# %%
filename_df['features'][0].shape[0]
# Out:
# 60

# %%
feature_shape = filename_df['features'][0].shape[0]

# %%
# number of classes (label categories)
num_labels=y.shape[1]

print(num_labels)
# Out:
# 7

# %%
model=Sequential()
###first layer
model.add(Dense(256,input_shape=(feature_shape,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###second layer
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###third layer
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###final layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 256)               15616
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  activation_4 (Activation)   (None, 128)               0
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  activation_5 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 7)                 455
#
#  activation_6 (Activation)   (None, 7)                 0
#
# =================================================================
# Total params: 57,223
# Trainable params: 57,223
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
num_epochs = 200
num_batch_size = 32

start = datetime.now()
model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), verbose=2)
duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/200
# 25/25 - 2s - loss: 24.9545 - accuracy: 0.1289 - val_loss: 1.9075 - val_accuracy: 0.2900 - 2s/epoch - 69ms/step
# Epoch 2/200
# 25/25 - 0s - loss: 9.8158 - accuracy: 0.1665 - val_loss: 1.8709 - val_accuracy: 0.2100 - 177ms/epoch - 7ms/step
# Epoch 3/200
# 25/25 - 0s - loss: 5.7308 - accuracy: 0.1539 - val_loss: 1.9045 - val_accuracy: 0.2250 - 172ms/epoch - 7ms/step
# Epoch 4/200
# 25/25 - 0s - loss: 4.2478 - accuracy: 0.1452 - val_loss: 1.8854 - val_accuracy: 0.2900 - 175ms/epoch - 7ms/step
# Epoch 5/200
# 25/25 - 0s - loss: 3.4338 - accuracy: 0.1414 - val_loss: 1.8908 - val_accuracy: 0.2600 - 183ms/epoch - 7ms/step
# Epoch 6/200
# 25/25 - 0s - loss: 2.7705 - accuracy: 0.1602 - val_loss: 1.9006 - val_accuracy: 0.2500 - 175ms/epoch - 7ms/step
# Epoch 7/200
# 25/25 - 0s - loss: 2.5113 - accuracy: 0.1677 - val_loss: 1.9266 - val_accuracy: 0.1800 - 181ms/epoch - 7ms/step
# Epoch 8/200
# 25/25 - 0s - loss: 2.3546 - accuracy: 0.1790 - val_loss: 1.9324 - val_accuracy: 0.1150 - 177ms/epoch - 7ms/step
# Epoch 9/200
# 25/25 - 0s - loss: 2.2042 - accuracy: 0.1740 - val_loss: 1.9414 - val_accuracy: 0.1100 - 176ms/epoch - 7ms/step
# Epoch 10/200
# 25/25 - 0s - loss: 2.2133 - accuracy: 0.1715 - val_loss: 1.9350 - val_accuracy: 0.1300 - 174ms/epoch - 7ms/step
# Epoch 11/200
# 25/25 - 0s - loss: 2.1296 - accuracy: 0.1564 - val_loss: 1.9302 - val_accuracy: 0.1350 - 175ms/epoch - 7ms/step
# Epoch 12/200
# 25/25 - 0s - loss: 2.0576 - accuracy: 0.1677 - val_loss: 1.9246 - val_accuracy: 0.1350 - 180ms/epoch - 7ms/step
# Epoch 13/200
# 25/25 - 0s - loss: 2.0512 - accuracy: 0.1690 - val_loss: 1.9409 - val_accuracy: 0.1350 - 180ms/epoch - 7ms/step
# Epoch 14/200
# 25/25 - 0s - loss: 2.0433 - accuracy: 0.1615 - val_loss: 1.9414 - val_accuracy: 0.1350 - 182ms/epoch - 7ms/step
# Epoch 15/200
# 25/25 - 0s - loss: 1.9988 - accuracy: 0.1627 - val_loss: 1.9417 - val_accuracy: 0.1400 - 175ms/epoch - 7ms/step
# Epoch 16/200
# 25/25 - 0s - loss: 1.9615 - accuracy: 0.1727 - val_loss: 1.9346 - val_accuracy: 0.1400 - 179ms/epoch - 7ms/step
# Epoch 17/200
# 25/25 - 0s - loss: 2.0051 - accuracy: 0.1589 - val_loss: 1.9253 - val_accuracy: 0.1400 - 170ms/epoch - 7ms/step
# Epoch 18/200
# 25/25 - 0s - loss: 1.9859 - accuracy: 0.1752 - val_loss: 1.9179 - val_accuracy: 0.1350 - 174ms/epoch - 7ms/step
# Epoch 19/200
# 25/25 - 0s - loss: 1.9542 - accuracy: 0.1790 - val_loss: 1.8747 - val_accuracy: 0.1950 - 173ms/epoch - 7ms/step
# Epoch 20/200
# 25/25 - 0s - loss: 1.9598 - accuracy: 0.2003 - val_loss: 1.9170 - val_accuracy: 0.1850 - 178ms/epoch - 7ms/step
# Epoch 21/200
# 25/25 - 0s - loss: 1.9757 - accuracy: 0.1902 - val_loss: 1.8985 - val_accuracy: 0.2050 - 172ms/epoch - 7ms/step
# Epoch 22/200
# 25/25 - 0s - loss: 1.9091 - accuracy: 0.1827 - val_loss: 1.8544 - val_accuracy: 0.1750 - 176ms/epoch - 7ms/step
# Epoch 23/200
# 25/25 - 0s - loss: 1.9462 - accuracy: 0.1915 - val_loss: 1.8807 - val_accuracy: 0.1950 - 183ms/epoch - 7ms/step
# Epoch 24/200
# 25/25 - 0s - loss: 1.9374 - accuracy: 0.2065 - val_loss: 1.8546 - val_accuracy: 0.1900 - 174ms/epoch - 7ms/step
# Epoch 25/200
# 25/25 - 0s - loss: 1.9103 - accuracy: 0.2103 - val_loss: 1.8488 - val_accuracy: 0.1950 - 173ms/epoch - 7ms/step
# Epoch 26/200
# 25/25 - 0s - loss: 1.9229 - accuracy: 0.1940 - val_loss: 1.8269 - val_accuracy: 0.2250 - 173ms/epoch - 7ms/step
# Epoch 27/200
# 25/25 - 0s - loss: 1.9026 - accuracy: 0.2140 - val_loss: 1.8269 - val_accuracy: 0.2350 - 180ms/epoch - 7ms/step
# Epoch 28/200
# 25/25 - 0s - loss: 1.8816 - accuracy: 0.2228 - val_loss: 1.8110 - val_accuracy: 0.2700 - 176ms/epoch - 7ms/step
# Epoch 29/200
# 25/25 - 0s - loss: 1.8633 - accuracy: 0.2403 - val_loss: 1.7873 - val_accuracy: 0.3250 - 173ms/epoch - 7ms/step
# Epoch 30/200
# 25/25 - 0s - loss: 1.8479 - accuracy: 0.2265 - val_loss: 1.7987 - val_accuracy: 0.3050 - 172ms/epoch - 7ms/step
# Epoch 31/200
# 25/25 - 0s - loss: 1.8303 - accuracy: 0.2416 - val_loss: 1.7425 - val_accuracy: 0.2800 - 174ms/epoch - 7ms/step
# Epoch 32/200
# 25/25 - 0s - loss: 1.8578 - accuracy: 0.2240 - val_loss: 1.7532 - val_accuracy: 0.3050 - 179ms/epoch - 7ms/step
# Epoch 33/200
# 25/25 - 0s - loss: 1.8395 - accuracy: 0.2390 - val_loss: 1.7379 - val_accuracy: 0.3200 - 180ms/epoch - 7ms/step
# Epoch 34/200
# 25/25 - 0s - loss: 1.8140 - accuracy: 0.2778 - val_loss: 1.6946 - val_accuracy: 0.2900 - 178ms/epoch - 7ms/step
# Epoch 35/200
# 25/25 - 0s - loss: 1.8421 - accuracy: 0.2578 - val_loss: 1.7154 - val_accuracy: 0.3200 - 195ms/epoch - 8ms/step
# Epoch 36/200
# 25/25 - 0s - loss: 1.8044 - accuracy: 0.2466 - val_loss: 1.6992 - val_accuracy: 0.3200 - 177ms/epoch - 7ms/step
# Epoch 37/200
# 25/25 - 0s - loss: 1.8000 - accuracy: 0.2841 - val_loss: 1.6588 - val_accuracy: 0.3050 - 180ms/epoch - 7ms/step
# Epoch 38/200
# 25/25 - 0s - loss: 1.7684 - accuracy: 0.2628 - val_loss: 1.6543 - val_accuracy: 0.3350 - 183ms/epoch - 7ms/step
# Epoch 39/200
# 25/25 - 0s - loss: 1.7866 - accuracy: 0.2791 - val_loss: 1.6195 - val_accuracy: 0.3300 - 177ms/epoch - 7ms/step
# Epoch 40/200
# 25/25 - 0s - loss: 1.7623 - accuracy: 0.2566 - val_loss: 1.6142 - val_accuracy: 0.3350 - 174ms/epoch - 7ms/step
# Epoch 41/200
# 25/25 - 0s - loss: 1.7583 - accuracy: 0.2904 - val_loss: 1.6280 - val_accuracy: 0.3450 - 172ms/epoch - 7ms/step
# Epoch 42/200
# 25/25 - 0s - loss: 1.7141 - accuracy: 0.2816 - val_loss: 1.5893 - val_accuracy: 0.3200 - 177ms/epoch - 7ms/step
# Epoch 43/200
# 25/25 - 0s - loss: 1.7309 - accuracy: 0.2728 - val_loss: 1.6131 - val_accuracy: 0.3400 - 176ms/epoch - 7ms/step
# Epoch 44/200
# 25/25 - 0s - loss: 1.7428 - accuracy: 0.2879 - val_loss: 1.5844 - val_accuracy: 0.3350 - 207ms/epoch - 8ms/step
# Epoch 45/200
# 25/25 - 0s - loss: 1.6877 - accuracy: 0.2891 - val_loss: 1.5504 - val_accuracy: 0.3250 - 170ms/epoch - 7ms/step
# Epoch 46/200
# 25/25 - 0s - loss: 1.6528 - accuracy: 0.2979 - val_loss: 1.5246 - val_accuracy: 0.3400 - 180ms/epoch - 7ms/step
# Epoch 47/200
# 25/25 - 0s - loss: 1.6735 - accuracy: 0.3029 - val_loss: 1.5379 - val_accuracy: 0.3450 - 173ms/epoch - 7ms/step
# Epoch 48/200
# 25/25 - 0s - loss: 1.6320 - accuracy: 0.3229 - val_loss: 1.5047 - val_accuracy: 0.3700 - 172ms/epoch - 7ms/step
# Epoch 49/200
# 25/25 - 0s - loss: 1.6792 - accuracy: 0.2791 - val_loss: 1.5088 - val_accuracy: 0.4000 - 175ms/epoch - 7ms/step
# Epoch 50/200
# 25/25 - 0s - loss: 1.6359 - accuracy: 0.3242 - val_loss: 1.4986 - val_accuracy: 0.3550 - 185ms/epoch - 7ms/step
# Epoch 51/200
# 25/25 - 0s - loss: 1.5993 - accuracy: 0.3254 - val_loss: 1.4489 - val_accuracy: 0.3700 - 181ms/epoch - 7ms/step
# Epoch 52/200
# 25/25 - 0s - loss: 1.5965 - accuracy: 0.3166 - val_loss: 1.4514 - val_accuracy: 0.3650 - 172ms/epoch - 7ms/step
# Epoch 53/200
# 25/25 - 0s - loss: 1.6381 - accuracy: 0.3091 - val_loss: 1.4524 - val_accuracy: 0.4050 - 172ms/epoch - 7ms/step
# Epoch 54/200
# 25/25 - 0s - loss: 1.6061 - accuracy: 0.3217 - val_loss: 1.4588 - val_accuracy: 0.3500 - 176ms/epoch - 7ms/step
# Epoch 55/200
# 25/25 - 0s - loss: 1.6024 - accuracy: 0.3267 - val_loss: 1.4116 - val_accuracy: 0.3750 - 175ms/epoch - 7ms/step
# Epoch 56/200
# 25/25 - 0s - loss: 1.5577 - accuracy: 0.3379 - val_loss: 1.3944 - val_accuracy: 0.3750 - 167ms/epoch - 7ms/step
# Epoch 57/200
# 25/25 - 0s - loss: 1.5003 - accuracy: 0.3705 - val_loss: 1.3629 - val_accuracy: 0.4000 - 178ms/epoch - 7ms/step
# Epoch 58/200
# 25/25 - 0s - loss: 1.5728 - accuracy: 0.3417 - val_loss: 1.3583 - val_accuracy: 0.3900 - 181ms/epoch - 7ms/step
# Epoch 59/200
# 25/25 - 0s - loss: 1.5217 - accuracy: 0.3680 - val_loss: 1.3727 - val_accuracy: 0.4600 - 179ms/epoch - 7ms/step
# Epoch 60/200
# 25/25 - 0s - loss: 1.5274 - accuracy: 0.3392 - val_loss: 1.3273 - val_accuracy: 0.4450 - 179ms/epoch - 7ms/step
# Epoch 61/200
# 25/25 - 0s - loss: 1.5201 - accuracy: 0.3867 - val_loss: 1.3246 - val_accuracy: 0.5150 - 174ms/epoch - 7ms/step
# Epoch 62/200
# 25/25 - 0s - loss: 1.4716 - accuracy: 0.3742 - val_loss: 1.3156 - val_accuracy: 0.4400 - 185ms/epoch - 7ms/step
# Epoch 63/200
# 25/25 - 0s - loss: 1.4619 - accuracy: 0.3792 - val_loss: 1.3071 - val_accuracy: 0.4750 - 169ms/epoch - 7ms/step
# Epoch 64/200
# 25/25 - 0s - loss: 1.4689 - accuracy: 0.3692 - val_loss: 1.3086 - val_accuracy: 0.4500 - 175ms/epoch - 7ms/step
# Epoch 65/200
# 25/25 - 0s - loss: 1.4591 - accuracy: 0.3980 - val_loss: 1.2766 - val_accuracy: 0.4600 - 181ms/epoch - 7ms/step
# Epoch 66/200
# 25/25 - 0s - loss: 1.4247 - accuracy: 0.3967 - val_loss: 1.2877 - val_accuracy: 0.4550 - 173ms/epoch - 7ms/step
# Epoch 67/200
# 25/25 - 0s - loss: 1.4119 - accuracy: 0.4218 - val_loss: 1.2574 - val_accuracy: 0.4550 - 199ms/epoch - 8ms/step
# Epoch 68/200
# 25/25 - 0s - loss: 1.4483 - accuracy: 0.3717 - val_loss: 1.2549 - val_accuracy: 0.5150 - 202ms/epoch - 8ms/step
# Epoch 69/200
# 25/25 - 0s - loss: 1.3956 - accuracy: 0.4255 - val_loss: 1.2318 - val_accuracy: 0.4900 - 219ms/epoch - 9ms/step
# Epoch 70/200
# 25/25 - 0s - loss: 1.3565 - accuracy: 0.4305 - val_loss: 1.2259 - val_accuracy: 0.5750 - 238ms/epoch - 10ms/step
# Epoch 71/200
# 25/25 - 0s - loss: 1.3885 - accuracy: 0.4168 - val_loss: 1.2300 - val_accuracy: 0.5450 - 269ms/epoch - 11ms/step
# Epoch 72/200
# 25/25 - 0s - loss: 1.3573 - accuracy: 0.4481 - val_loss: 1.2085 - val_accuracy: 0.4950 - 275ms/epoch - 11ms/step
# Epoch 73/200
# 25/25 - 0s - loss: 1.3702 - accuracy: 0.3930 - val_loss: 1.2833 - val_accuracy: 0.5950 - 294ms/epoch - 12ms/step
# Epoch 74/200
# 25/25 - 0s - loss: 1.3734 - accuracy: 0.4255 - val_loss: 1.2152 - val_accuracy: 0.5600 - 299ms/epoch - 12ms/step
# Epoch 75/200
# 25/25 - 0s - loss: 1.3384 - accuracy: 0.4268 - val_loss: 1.1839 - val_accuracy: 0.4850 - 317ms/epoch - 13ms/step
# Epoch 76/200
# 25/25 - 0s - loss: 1.3650 - accuracy: 0.4180 - val_loss: 1.1784 - val_accuracy: 0.5400 - 298ms/epoch - 12ms/step
# Epoch 77/200
# 25/25 - 0s - loss: 1.3045 - accuracy: 0.4543 - val_loss: 1.1616 - val_accuracy: 0.6000 - 307ms/epoch - 12ms/step
# Epoch 78/200
# 25/25 - 0s - loss: 1.2697 - accuracy: 0.4819 - val_loss: 1.1559 - val_accuracy: 0.5500 - 274ms/epoch - 11ms/step
# Epoch 79/200
# 25/25 - 0s - loss: 1.2884 - accuracy: 0.4931 - val_loss: 1.1015 - val_accuracy: 0.5800 - 273ms/epoch - 11ms/step
# Epoch 80/200
# 25/25 - 0s - loss: 1.2717 - accuracy: 0.4718 - val_loss: 1.1063 - val_accuracy: 0.6200 - 269ms/epoch - 11ms/step
# Epoch 81/200
# 25/25 - 0s - loss: 1.3303 - accuracy: 0.4443 - val_loss: 1.0979 - val_accuracy: 0.6600 - 254ms/epoch - 10ms/step
# Epoch 82/200
# 25/25 - 0s - loss: 1.2353 - accuracy: 0.5069 - val_loss: 1.0788 - val_accuracy: 0.5850 - 258ms/epoch - 10ms/step
# Epoch 83/200
# 25/25 - 0s - loss: 1.2518 - accuracy: 0.4956 - val_loss: 1.0660 - val_accuracy: 0.6450 - 254ms/epoch - 10ms/step
# Epoch 84/200
# 25/25 - 0s - loss: 1.3133 - accuracy: 0.4856 - val_loss: 1.0569 - val_accuracy: 0.6450 - 255ms/epoch - 10ms/step
# Epoch 85/200
# 25/25 - 0s - loss: 1.2190 - accuracy: 0.5106 - val_loss: 1.0403 - val_accuracy: 0.6100 - 244ms/epoch - 10ms/step
# Epoch 86/200
# 25/25 - 0s - loss: 1.2199 - accuracy: 0.5044 - val_loss: 1.0463 - val_accuracy: 0.6700 - 237ms/epoch - 9ms/step
# Epoch 87/200
# 25/25 - 0s - loss: 1.2184 - accuracy: 0.5081 - val_loss: 1.0469 - val_accuracy: 0.6750 - 215ms/epoch - 9ms/step
# Epoch 88/200
# 25/25 - 0s - loss: 1.1714 - accuracy: 0.5394 - val_loss: 1.0006 - val_accuracy: 0.6250 - 204ms/epoch - 8ms/step
# Epoch 89/200
# 25/25 - 0s - loss: 1.1380 - accuracy: 0.5169 - val_loss: 0.9343 - val_accuracy: 0.7050 - 202ms/epoch - 8ms/step
# Epoch 90/200
# 25/25 - 0s - loss: 1.1093 - accuracy: 0.5407 - val_loss: 0.9528 - val_accuracy: 0.6450 - 217ms/epoch - 9ms/step
# Epoch 91/200
# 25/25 - 0s - loss: 1.1019 - accuracy: 0.5432 - val_loss: 0.9084 - val_accuracy: 0.6700 - 230ms/epoch - 9ms/step
# Epoch 92/200
# 25/25 - 0s - loss: 1.0861 - accuracy: 0.5432 - val_loss: 0.8891 - val_accuracy: 0.6550 - 233ms/epoch - 9ms/step
# Epoch 93/200
# 25/25 - 0s - loss: 1.0488 - accuracy: 0.5870 - val_loss: 0.8682 - val_accuracy: 0.7250 - 242ms/epoch - 10ms/step
# Epoch 94/200
# 25/25 - 0s - loss: 1.1288 - accuracy: 0.5469 - val_loss: 0.8923 - val_accuracy: 0.7150 - 239ms/epoch - 10ms/step
# Epoch 95/200
# 25/25 - 0s - loss: 1.0741 - accuracy: 0.5970 - val_loss: 0.8550 - val_accuracy: 0.7050 - 240ms/epoch - 10ms/step
# Epoch 96/200
# 25/25 - 0s - loss: 1.0722 - accuracy: 0.5732 - val_loss: 0.9079 - val_accuracy: 0.6550 - 235ms/epoch - 9ms/step
# Epoch 97/200
# 25/25 - 0s - loss: 1.0596 - accuracy: 0.5932 - val_loss: 0.8419 - val_accuracy: 0.6450 - 241ms/epoch - 10ms/step
# Epoch 98/200
# 25/25 - 0s - loss: 0.9896 - accuracy: 0.5795 - val_loss: 0.8003 - val_accuracy: 0.6750 - 238ms/epoch - 10ms/step
# Epoch 99/200
# 25/25 - 0s - loss: 1.0652 - accuracy: 0.5870 - val_loss: 0.8533 - val_accuracy: 0.6650 - 237ms/epoch - 9ms/step
# Epoch 100/200
# 25/25 - 0s - loss: 0.9923 - accuracy: 0.6108 - val_loss: 0.8040 - val_accuracy: 0.7050 - 244ms/epoch - 10ms/step
# Epoch 101/200
# 25/25 - 0s - loss: 1.0137 - accuracy: 0.6195 - val_loss: 0.7842 - val_accuracy: 0.7000 - 282ms/epoch - 11ms/step
# Epoch 102/200
# 25/25 - 0s - loss: 0.9305 - accuracy: 0.6108 - val_loss: 0.7617 - val_accuracy: 0.7400 - 328ms/epoch - 13ms/step
# Epoch 103/200
# 25/25 - 0s - loss: 1.0076 - accuracy: 0.6220 - val_loss: 0.7956 - val_accuracy: 0.7300 - 292ms/epoch - 12ms/step
# Epoch 104/200
# 25/25 - 0s - loss: 0.9423 - accuracy: 0.6295 - val_loss: 0.7488 - val_accuracy: 0.7350 - 276ms/epoch - 11ms/step
# Epoch 105/200
# 25/25 - 0s - loss: 0.9824 - accuracy: 0.6195 - val_loss: 0.7433 - val_accuracy: 0.7000 - 257ms/epoch - 10ms/step
# Epoch 106/200
# 25/25 - 0s - loss: 0.9236 - accuracy: 0.6471 - val_loss: 0.7488 - val_accuracy: 0.6850 - 252ms/epoch - 10ms/step
# Epoch 107/200
# 25/25 - 0s - loss: 0.9328 - accuracy: 0.6208 - val_loss: 0.7655 - val_accuracy: 0.7150 - 236ms/epoch - 9ms/step
# Epoch 108/200
# 25/25 - 0s - loss: 0.9148 - accuracy: 0.6333 - val_loss: 0.7136 - val_accuracy: 0.7150 - 239ms/epoch - 10ms/step
# Epoch 109/200
# 25/25 - 0s - loss: 0.8511 - accuracy: 0.6859 - val_loss: 0.8128 - val_accuracy: 0.6950 - 238ms/epoch - 10ms/step
# Epoch 110/200
# 25/25 - 0s - loss: 0.9078 - accuracy: 0.6471 - val_loss: 0.7242 - val_accuracy: 0.6800 - 237ms/epoch - 9ms/step
# Epoch 111/200
# 25/25 - 0s - loss: 0.9512 - accuracy: 0.6333 - val_loss: 0.7287 - val_accuracy: 0.7300 - 221ms/epoch - 9ms/step
# Epoch 112/200
# 25/25 - 0s - loss: 0.9172 - accuracy: 0.6508 - val_loss: 0.7303 - val_accuracy: 0.7700 - 201ms/epoch - 8ms/step
# Epoch 113/200
# 25/25 - 0s - loss: 0.9166 - accuracy: 0.6546 - val_loss: 0.7351 - val_accuracy: 0.7550 - 197ms/epoch - 8ms/step
# Epoch 114/200
# 25/25 - 0s - loss: 0.8467 - accuracy: 0.6721 - val_loss: 0.6539 - val_accuracy: 0.7700 - 204ms/epoch - 8ms/step
# Epoch 115/200
# 25/25 - 0s - loss: 0.8460 - accuracy: 0.6683 - val_loss: 0.6992 - val_accuracy: 0.7600 - 216ms/epoch - 9ms/step
# Epoch 116/200
# 25/25 - 0s - loss: 0.8976 - accuracy: 0.6683 - val_loss: 0.7205 - val_accuracy: 0.7000 - 235ms/epoch - 9ms/step
# Epoch 117/200
# 25/25 - 0s - loss: 0.8492 - accuracy: 0.6783 - val_loss: 0.7395 - val_accuracy: 0.7700 - 299ms/epoch - 12ms/step
# Epoch 118/200
# 25/25 - 0s - loss: 0.8243 - accuracy: 0.6809 - val_loss: 0.6722 - val_accuracy: 0.7800 - 275ms/epoch - 11ms/step
# Epoch 119/200
# 25/25 - 0s - loss: 0.8237 - accuracy: 0.6783 - val_loss: 0.6873 - val_accuracy: 0.7650 - 263ms/epoch - 11ms/step
# Epoch 120/200
# 25/25 - 0s - loss: 0.8723 - accuracy: 0.6621 - val_loss: 0.6800 - val_accuracy: 0.7250 - 254ms/epoch - 10ms/step
# Epoch 121/200
# 25/25 - 0s - loss: 0.8267 - accuracy: 0.6733 - val_loss: 0.6403 - val_accuracy: 0.8000 - 236ms/epoch - 9ms/step
# Epoch 122/200
# 25/25 - 0s - loss: 0.8514 - accuracy: 0.6733 - val_loss: 0.6811 - val_accuracy: 0.7800 - 238ms/epoch - 10ms/step
# Epoch 123/200
# 25/25 - 0s - loss: 0.8473 - accuracy: 0.6733 - val_loss: 0.6616 - val_accuracy: 0.7300 - 248ms/epoch - 10ms/step
# Epoch 124/200
# 25/25 - 0s - loss: 0.7632 - accuracy: 0.7071 - val_loss: 0.6493 - val_accuracy: 0.7750 - 242ms/epoch - 10ms/step
# Epoch 125/200
# 25/25 - 0s - loss: 0.8015 - accuracy: 0.6959 - val_loss: 0.6378 - val_accuracy: 0.7850 - 231ms/epoch - 9ms/step
# Epoch 126/200
# 25/25 - 0s - loss: 0.8319 - accuracy: 0.6946 - val_loss: 0.7121 - val_accuracy: 0.6850 - 215ms/epoch - 9ms/step
# Epoch 127/200
# 25/25 - 0s - loss: 0.7803 - accuracy: 0.7171 - val_loss: 0.6667 - val_accuracy: 0.7500 - 204ms/epoch - 8ms/step
# Epoch 128/200
# 25/25 - 0s - loss: 0.8100 - accuracy: 0.6796 - val_loss: 0.6660 - val_accuracy: 0.7750 - 207ms/epoch - 8ms/step
# Epoch 129/200
# 25/25 - 0s - loss: 0.7083 - accuracy: 0.7409 - val_loss: 0.6321 - val_accuracy: 0.7450 - 219ms/epoch - 9ms/step
# Epoch 130/200
# 25/25 - 0s - loss: 0.8255 - accuracy: 0.6859 - val_loss: 0.6432 - val_accuracy: 0.7900 - 227ms/epoch - 9ms/step
# Epoch 131/200
# 25/25 - 0s - loss: 0.7466 - accuracy: 0.7234 - val_loss: 0.6038 - val_accuracy: 0.7600 - 226ms/epoch - 9ms/step
# Epoch 132/200
# 25/25 - 0s - loss: 0.7484 - accuracy: 0.7222 - val_loss: 0.6267 - val_accuracy: 0.7700 - 227ms/epoch - 9ms/step
# Epoch 133/200
# 25/25 - 0s - loss: 0.7480 - accuracy: 0.7284 - val_loss: 0.6202 - val_accuracy: 0.8050 - 226ms/epoch - 9ms/step
# Epoch 134/200
# 25/25 - 0s - loss: 0.7746 - accuracy: 0.7209 - val_loss: 0.6447 - val_accuracy: 0.7400 - 225ms/epoch - 9ms/step
# Epoch 135/200
# 25/25 - 0s - loss: 0.7290 - accuracy: 0.7397 - val_loss: 0.6192 - val_accuracy: 0.7900 - 243ms/epoch - 10ms/step
# Epoch 136/200
# 25/25 - 0s - loss: 0.7467 - accuracy: 0.7059 - val_loss: 0.6110 - val_accuracy: 0.8000 - 239ms/epoch - 10ms/step
# Epoch 137/200
# 25/25 - 0s - loss: 0.7383 - accuracy: 0.7284 - val_loss: 0.6004 - val_accuracy: 0.8000 - 242ms/epoch - 10ms/step
# Epoch 138/200
# 25/25 - 0s - loss: 0.8001 - accuracy: 0.7096 - val_loss: 0.6396 - val_accuracy: 0.7900 - 283ms/epoch - 11ms/step
# Epoch 139/200
# 25/25 - 0s - loss: 0.7212 - accuracy: 0.7322 - val_loss: 0.5711 - val_accuracy: 0.7900 - 281ms/epoch - 11ms/step
# Epoch 140/200
# 25/25 - 0s - loss: 0.6403 - accuracy: 0.7710 - val_loss: 0.6158 - val_accuracy: 0.7700 - 265ms/epoch - 11ms/step
# Epoch 141/200
# 25/25 - 0s - loss: 0.6688 - accuracy: 0.7597 - val_loss: 0.5601 - val_accuracy: 0.8250 - 257ms/epoch - 10ms/step
# Epoch 142/200
# 25/25 - 0s - loss: 0.7177 - accuracy: 0.7334 - val_loss: 0.6019 - val_accuracy: 0.7950 - 258ms/epoch - 10ms/step
# Epoch 143/200
# 25/25 - 0s - loss: 0.6810 - accuracy: 0.7522 - val_loss: 0.5910 - val_accuracy: 0.7800 - 254ms/epoch - 10ms/step
# Epoch 144/200
# 25/25 - 0s - loss: 0.6284 - accuracy: 0.7635 - val_loss: 0.5596 - val_accuracy: 0.7750 - 236ms/epoch - 9ms/step
# Epoch 145/200
# 25/25 - 0s - loss: 0.6533 - accuracy: 0.7710 - val_loss: 0.5847 - val_accuracy: 0.8350 - 239ms/epoch - 10ms/step
# Epoch 146/200
# 25/25 - 0s - loss: 0.6705 - accuracy: 0.7484 - val_loss: 0.5915 - val_accuracy: 0.7900 - 236ms/epoch - 9ms/step
# Epoch 147/200
# 25/25 - 0s - loss: 0.6457 - accuracy: 0.7635 - val_loss: 0.6050 - val_accuracy: 0.8100 - 213ms/epoch - 9ms/step
# Epoch 148/200
# 25/25 - 0s - loss: 0.7050 - accuracy: 0.7572 - val_loss: 0.5866 - val_accuracy: 0.7750 - 197ms/epoch - 8ms/step
# Epoch 149/200
# 25/25 - 0s - loss: 0.6957 - accuracy: 0.7572 - val_loss: 0.5508 - val_accuracy: 0.8200 - 200ms/epoch - 8ms/step
# Epoch 150/200
# 25/25 - 0s - loss: 0.6918 - accuracy: 0.7559 - val_loss: 0.5792 - val_accuracy: 0.8050 - 207ms/epoch - 8ms/step
# Epoch 151/200
# 25/25 - 0s - loss: 0.6366 - accuracy: 0.7660 - val_loss: 0.5603 - val_accuracy: 0.8350 - 214ms/epoch - 9ms/step
# Epoch 152/200
# 25/25 - 0s - loss: 0.6463 - accuracy: 0.7672 - val_loss: 0.5592 - val_accuracy: 0.8200 - 221ms/epoch - 9ms/step
# Epoch 153/200
# 25/25 - 0s - loss: 0.6379 - accuracy: 0.7747 - val_loss: 0.5216 - val_accuracy: 0.8300 - 223ms/epoch - 9ms/step
# Epoch 154/200
# 25/25 - 0s - loss: 0.6405 - accuracy: 0.7797 - val_loss: 0.5350 - val_accuracy: 0.8150 - 227ms/epoch - 9ms/step
# Epoch 155/200
# 25/25 - 0s - loss: 0.6282 - accuracy: 0.7610 - val_loss: 0.5817 - val_accuracy: 0.8150 - 242ms/epoch - 10ms/step
# Epoch 156/200
# 25/25 - 0s - loss: 0.6198 - accuracy: 0.8023 - val_loss: 0.5792 - val_accuracy: 0.8100 - 229ms/epoch - 9ms/step
# Epoch 157/200
# 25/25 - 0s - loss: 0.6290 - accuracy: 0.7785 - val_loss: 0.5720 - val_accuracy: 0.8050 - 224ms/epoch - 9ms/step
# Epoch 158/200
# 25/25 - 0s - loss: 0.6345 - accuracy: 0.7797 - val_loss: 0.5664 - val_accuracy: 0.8400 - 228ms/epoch - 9ms/step
# Epoch 159/200
# 25/25 - 0s - loss: 0.6193 - accuracy: 0.7785 - val_loss: 0.5455 - val_accuracy: 0.8200 - 239ms/epoch - 10ms/step
# Epoch 160/200
# 25/25 - 0s - loss: 0.6019 - accuracy: 0.7847 - val_loss: 0.5649 - val_accuracy: 0.8250 - 239ms/epoch - 10ms/step
# Epoch 161/200
# 25/25 - 0s - loss: 0.6246 - accuracy: 0.7760 - val_loss: 0.6060 - val_accuracy: 0.7750 - 224ms/epoch - 9ms/step
# Epoch 162/200
# 25/25 - 0s - loss: 0.6137 - accuracy: 0.7972 - val_loss: 0.5899 - val_accuracy: 0.8200 - 225ms/epoch - 9ms/step
# Epoch 163/200
# 25/25 - 0s - loss: 0.5762 - accuracy: 0.8060 - val_loss: 0.6129 - val_accuracy: 0.7800 - 226ms/epoch - 9ms/step
# Epoch 164/200
# 25/25 - 0s - loss: 0.6184 - accuracy: 0.7697 - val_loss: 0.5855 - val_accuracy: 0.8150 - 228ms/epoch - 9ms/step
# Epoch 165/200
# 25/25 - 0s - loss: 0.6303 - accuracy: 0.7810 - val_loss: 0.5718 - val_accuracy: 0.8050 - 249ms/epoch - 10ms/step
# Epoch 166/200
# 25/25 - 0s - loss: 0.6530 - accuracy: 0.7872 - val_loss: 0.5631 - val_accuracy: 0.8250 - 242ms/epoch - 10ms/step
# Epoch 167/200
# 25/25 - 0s - loss: 0.6452 - accuracy: 0.7760 - val_loss: 0.5656 - val_accuracy: 0.8200 - 237ms/epoch - 9ms/step
# Epoch 168/200
# 25/25 - 0s - loss: 0.6030 - accuracy: 0.7872 - val_loss: 0.5582 - val_accuracy: 0.8000 - 226ms/epoch - 9ms/step
# Epoch 169/200
# 25/25 - 0s - loss: 0.5816 - accuracy: 0.8210 - val_loss: 0.5893 - val_accuracy: 0.8050 - 225ms/epoch - 9ms/step
# Epoch 170/200
# 25/25 - 0s - loss: 0.5527 - accuracy: 0.8060 - val_loss: 0.6169 - val_accuracy: 0.8100 - 233ms/epoch - 9ms/step
# Epoch 171/200
# 25/25 - 0s - loss: 0.5598 - accuracy: 0.7997 - val_loss: 0.5714 - val_accuracy: 0.8150 - 287ms/epoch - 11ms/step
# Epoch 172/200
# 25/25 - 0s - loss: 0.5510 - accuracy: 0.8135 - val_loss: 0.5640 - val_accuracy: 0.8150 - 279ms/epoch - 11ms/step
# Epoch 173/200
# 25/25 - 0s - loss: 0.5487 - accuracy: 0.8123 - val_loss: 0.5449 - val_accuracy: 0.8350 - 259ms/epoch - 10ms/step
# Epoch 174/200
# 25/25 - 0s - loss: 0.5428 - accuracy: 0.8023 - val_loss: 0.5624 - val_accuracy: 0.8250 - 248ms/epoch - 10ms/step
# Epoch 175/200
# 25/25 - 0s - loss: 0.5763 - accuracy: 0.8023 - val_loss: 0.6297 - val_accuracy: 0.7650 - 238ms/epoch - 10ms/step
# Epoch 176/200
# 25/25 - 0s - loss: 0.5411 - accuracy: 0.8110 - val_loss: 0.5437 - val_accuracy: 0.8200 - 284ms/epoch - 11ms/step
# Epoch 177/200
# 25/25 - 0s - loss: 0.5799 - accuracy: 0.8110 - val_loss: 0.5091 - val_accuracy: 0.8350 - 238ms/epoch - 10ms/step
# Epoch 178/200
# 25/25 - 0s - loss: 0.5737 - accuracy: 0.8160 - val_loss: 0.5333 - val_accuracy: 0.8200 - 237ms/epoch - 9ms/step
# Epoch 179/200
# 25/25 - 0s - loss: 0.6081 - accuracy: 0.8185 - val_loss: 0.5106 - val_accuracy: 0.8300 - 225ms/epoch - 9ms/step
# Epoch 180/200
# 25/25 - 0s - loss: 0.5769 - accuracy: 0.8098 - val_loss: 0.5519 - val_accuracy: 0.8250 - 210ms/epoch - 8ms/step
# Epoch 181/200
# 25/25 - 0s - loss: 0.5035 - accuracy: 0.8210 - val_loss: 0.5363 - val_accuracy: 0.8300 - 199ms/epoch - 8ms/step
# Epoch 182/200
# 25/25 - 0s - loss: 0.5635 - accuracy: 0.8148 - val_loss: 0.5654 - val_accuracy: 0.8050 - 205ms/epoch - 8ms/step
# Epoch 183/200
# 25/25 - 0s - loss: 0.4996 - accuracy: 0.8285 - val_loss: 0.5415 - val_accuracy: 0.8300 - 209ms/epoch - 8ms/step
# Epoch 184/200
# 25/25 - 0s - loss: 0.5601 - accuracy: 0.8135 - val_loss: 0.6578 - val_accuracy: 0.7800 - 216ms/epoch - 9ms/step
# Epoch 185/200
# 25/25 - 0s - loss: 0.5006 - accuracy: 0.8260 - val_loss: 0.5697 - val_accuracy: 0.8150 - 230ms/epoch - 9ms/step
# Epoch 186/200
# 25/25 - 0s - loss: 0.5180 - accuracy: 0.8248 - val_loss: 0.5757 - val_accuracy: 0.8350 - 226ms/epoch - 9ms/step
# Epoch 187/200
# 25/25 - 0s - loss: 0.4684 - accuracy: 0.8385 - val_loss: 0.5431 - val_accuracy: 0.8200 - 228ms/epoch - 9ms/step
# Epoch 188/200
# 25/25 - 0s - loss: 0.4726 - accuracy: 0.8423 - val_loss: 0.5156 - val_accuracy: 0.8200 - 224ms/epoch - 9ms/step
# Epoch 189/200
# 25/25 - 0s - loss: 0.5380 - accuracy: 0.8073 - val_loss: 0.5268 - val_accuracy: 0.8200 - 226ms/epoch - 9ms/step
# Epoch 190/200
# 25/25 - 0s - loss: 0.5065 - accuracy: 0.8310 - val_loss: 0.5494 - val_accuracy: 0.8350 - 224ms/epoch - 9ms/step
# Epoch 191/200
# 25/25 - 0s - loss: 0.5005 - accuracy: 0.8411 - val_loss: 0.5470 - val_accuracy: 0.8250 - 226ms/epoch - 9ms/step
# Epoch 192/200
# 25/25 - 0s - loss: 0.4688 - accuracy: 0.8511 - val_loss: 0.5713 - val_accuracy: 0.8350 - 225ms/epoch - 9ms/step
# Epoch 193/200
# 25/25 - 0s - loss: 0.5304 - accuracy: 0.8348 - val_loss: 0.5593 - val_accuracy: 0.8550 - 240ms/epoch - 10ms/step
# Epoch 194/200
# 25/25 - 0s - loss: 0.5430 - accuracy: 0.8160 - val_loss: 0.5883 - val_accuracy: 0.8150 - 227ms/epoch - 9ms/step
# Epoch 195/200
# 25/25 - 0s - loss: 0.5192 - accuracy: 0.8260 - val_loss: 0.6074 - val_accuracy: 0.8100 - 224ms/epoch - 9ms/step
# Epoch 196/200
# 25/25 - 0s - loss: 0.4623 - accuracy: 0.8436 - val_loss: 0.5789 - val_accuracy: 0.8100 - 227ms/epoch - 9ms/step
# Epoch 197/200
# 25/25 - 0s - loss: 0.4721 - accuracy: 0.8348 - val_loss: 0.5877 - val_accuracy: 0.8200 - 224ms/epoch - 9ms/step
# Epoch 198/200
# 25/25 - 0s - loss: 0.5004 - accuracy: 0.8436 - val_loss: 0.6143 - val_accuracy: 0.8150 - 226ms/epoch - 9ms/step
# Epoch 199/200
# 25/25 - 0s - loss: 0.5132 - accuracy: 0.8323 - val_loss: 0.5609 - val_accuracy: 0.8200 - 225ms/epoch - 9ms/step
# Epoch 200/200
# 25/25 - 0s - loss: 0.5049 - accuracy: 0.8385 - val_loss: 0.5212 - val_accuracy: 0.8400 - 226ms/epoch - 9ms/step
# Training completed in time:  0:00:46.732089

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.8399999737739563

# %%
predict_x=model.predict(X_test) 
classes_x=np.argmax(predict_x,axis=1)
predictions = np.array(classes_x)
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
true_labels_ytest = np.argmax(y_test,axis=1)

# %%
predictions_col = pd.Series(predictions)
true_col = pd.Series(true_labels_ytest)

# %%
prediction_df = pd.DataFrame({'predictions':predictions_col, 'true_label':true_col})

prediction_df.head()
# Out:
#    predictions  true_label
# 0            3           3
# 1            1           1
# 2            5           5
# 3            3           3
# 4            1           6

# %%
cm = pd.DataFrame(
    confusion_matrix(true_col, predictions_col),
    columns=['pred_iori',
             'pred_yamato',
            'pred_mitsuki',
            'pred_tamaki',
            'pred_sougo',
            'pred_nagi',
            'pred_riku'],
    index=['true_iori',
             'true_yamato',
            'true_mitsuki',
            'true_tamaki',
            'true_sougo',
            'true_nagi',
            'true_riku']
)

cm
# Out:
#               pred_iori  pred_yamato  pred_mitsuki  pred_tamaki  pred_sougo  \
# true_iori            30            0             0            1           3
# true_yamato           0           25             0            2           0
# true_mitsuki          0            0            23            0           2
# true_tamaki           0            1             0           20           1
# true_sougo            0            1             0            2          23
# true_nagi             2            0             1            1           0
# true_riku             0            5             0            2           0
#
#               pred_nagi  pred_riku
# true_iori             4          0
# true_yamato           0          1
# true_mitsuki          0          0
# true_tamaki           1          1
# true_sougo            1          0
# true_nagi            24          0
# true_riku             0         23

# %%
vocalists = ['iori', 'yamato', 'mitsuki', 'tamaki', 'sougo', 'nagi', 'riku']

# %%
print(classification_report(true_col, predictions_col, target_names=vocalists))
# Out:
#               precision    recall  f1-score   support
#
#         iori       0.94      0.79      0.86        38
#       yamato       0.78      0.89      0.83        28
#      mitsuki       0.96      0.92      0.94        25
#       tamaki       0.71      0.83      0.77        24
#        sougo       0.79      0.85      0.82        27
#         nagi       0.80      0.86      0.83        28
#         riku       0.92      0.77      0.84        30
#
#     accuracy                           0.84       200
#    macro avg       0.84      0.84      0.84       200
# weighted avg       0.85      0.84      0.84       200
